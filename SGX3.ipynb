# %% [markdown]
# <a href="https://colab.research.google.com/github/Whis101/Whis101-github.io/blob/main/SGX3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/sgx3 coding institute/ATX.csv")
# Out:
# <ipython-input-56-526376900>:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/sgx3 coding institute/ATX.csv")

# %%
df.head()
# Out:
#                                    Traffic Report ID  \
# 0  F350D780EA8AAA48030B4DB64F790C14DBCD757F_17096...
# 1  042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 2  BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_17080...
# 3  A5909010064EF753C5F090A07CFCDDFBF25E38F3_15865...
# 4  4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_16543...
#
#                  Published Date     Issue Reported  \
# 0  03/06/2024 01:29:39 AM +0000    Stalled Vehicle
# 1  03/06/2024 01:26:42 AM +0000       Crash Urgent
# 2  02/15/2024 10:17:48 PM +0000    LOOSE LIVESTOCK
# 3  04/10/2020 09:31:11 PM +0000  TRFC HAZD/ DEBRIS
# 4  06/04/2022 05:51:05 PM +0000     Traffic Hazard
#
#                        Location   Latitude  Longitude  \
# 0   POINT (-97.705874 30.32358)  30.323580 -97.705874
# 1  POINT (-97.698567 30.342505)  30.342505 -97.698567
# 2    POINT (-97.717911 30.0578)  30.057800 -97.717911
# 3  POINT (-97.866676 30.140878)  30.140878 -97.866676
# 4  POINT (-97.825791 30.455444)  30.455444 -97.825791
#
# ...

# %%
df.shape
# Out:
# (425641, 10)

# %%
df.columns
# Out:
# Index(['Traffic Report ID', 'Published Date', 'Issue Reported', 'Location',
#        'Latitude', 'Longitude', 'Address', 'Status', 'Status Date', 'Agency'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425641 entries, 0 to 425640
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Traffic Report ID  425641 non-null  object
#  1   Published Date     425641 non-null  object
#  2   Issue Reported     425641 non-null  object
#  3   Location           425376 non-null  object
#  4   Latitude           425562 non-null  float64
#  5   Longitude          425562 non-null  float64
#  6   Address            425641 non-null  object
#  7   Status             423948 non-null  object
#  8   Status Date        425641 non-null  object
#  9   Agency             69057 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 32.5+ MB

# %%
df.describe()
# Out:
#            Latitude      Longitude
# count  4.255620e+05  425562.000000
# mean   5.701659e+03     -97.518368
# std    4.110550e+05       4.544944
# min    0.000000e+00     -98.816154
# 25%    3.023067e+01     -97.776078
# 50%    3.029459e+01     -97.731703
# 75%    3.037432e+01     -97.680807
# max    2.999603e+07       0.000000

# %%
df['Issue Reported'].nunique()
# Out:
# 24

# %%
df[df['Issue Reported']=='Crash Urgent']
# Out:
#                                         Traffic Report ID  \
# 1       042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 6       09203A0B810D0C054F3F15D6DB42AA850BEA9174_17096...
# 12      9521E2BCC9C0DE945CCF68B52345097002B66BA5_17096...
# 14      E90E88C880E48E96024E634381BA1AD4888E72E0_17096...
# 17      7FCDB7BA6DE74B6E007EFE1079540E0228817D26_17096...
# ...                                                   ...
# 425608  823B29FFD8DBAB9367EDDCA53376226A17CDC00F_17496...
# 425611  88C79C1DC9D13B2B592B9057730DF504809A43C1_17496...
# 425615  F4F9DD8C2988666B84167D2D7E58D654A53560A1_17496...
# 425618  FFEEAE89101150B85AC054F8625E928F11D2FBB0_17496...
# 425628  72448B7792D7AA9BAE361029D06BB23AD7803155_17496...
#
#                       Published Date Issue Reported  \
# 1       03/06/2024 01:26:42 AM +0000   Crash Urgent
# 6       03/05/2024 11:34:06 PM +0000   Crash Urgent
# 12      03/06/2024 02:45:22 AM +0000   Crash Urgent
# 14      03/06/2024 02:04:19 AM +0000   Crash Urgent
# ...

# %%
df[df['Address'].str.contains('IH 35',na=False)&(df['Issue Reported']=='Crash Urgent')]
# Out:
#                                         Traffic Report ID  \
# 17      7FCDB7BA6DE74B6E007EFE1079540E0228817D26_17096...
# 149     508DE84D9E60D0EA4F80173324A7A9CC95DBEDB3_17122...
# 213     5F5898E4726001663BA5A126B313B03B1AED3F07_17097...
# 215     EC10DB9185C9C58A004FA683DD21AFCD16CAD418_17109...
# 289     BA2E8AA59E4161EE5807078F7226C405FDE751A6_15609...
# ...                                                   ...
# 424561  BF106F603F5A1CA065CB9438FB4EAE247D89AEF3_17488...
# 424688  A02A2FE9596BF1F59BD4CA2ECA3885C814393F10_17489...
# 424734  9304739C29A855AF7DDB1CFC420CB7CF57726E00_17489...
# 425415  6DBB169C06C09B479392E3A636171E8714B46023_17494...
# 425615  F4F9DD8C2988666B84167D2D7E58D654A53560A1_17496...
#
#                       Published Date Issue Reported  \
# 17      03/06/2024 02:30:38 AM +0000   Crash Urgent
# 149     04/04/2024 09:57:57 PM +0000   Crash Urgent
# 213     03/06/2024 04:59:46 PM +0000   Crash Urgent
# 215     03/20/2024 02:29:08 PM +0000   Crash Urgent
# ...

# %%
df['Published Date'] = pd.to_datetime(df['Published Date'])

# %%
df[(df['Issue Reported']=='Traffic Hazard')&(df['Published Date'].dt.year==2023)]
# Out:
#                                         Traffic Report ID  \
# 90700   83DE061FB52099B8B9B03B3AE4E888D6B10D9E5E_16829...
# 91905   D74A123791C30D807F7CB512416368B3489DBAC5_16837...
# 120446  3B987A82043F7DF95B5784095B5CE3BB870DC709_16935...
# 152251  B32BDC3918665A3A1B8C43BCF903A4A79E9A76FB_17033...
# 152255  827AC818D422F57B93682A8478AFA2D4F026513D_17038...
# ...                                                   ...
# 224708  C60D81F35D8BE966FA0437E43F1FEFF777C6E121_17028...
# 224709  8334918DA76533B5C14F235F374E327C95035AA3_17028...
# 224712  0D467C11C1F788A43266782AAC388B66B0F22551_17028...
# 224727  A9124EF9C8C2B13244A095F46BD6E50CAAA5BE7D_17028...
# 224751  3433C310742F1C73C2CD2622BFC3CFB7C6D25350_17029...
#
#                   Published Date  Issue Reported  \
# 90700  2023-05-01 05:08:41+00:00  Traffic Hazard
# 91905  2023-05-11 01:02:50+00:00  Traffic Hazard
# 120446 2023-08-31 18:28:56+00:00  Traffic Hazard
# 152251 2023-12-23 16:05:04+00:00  Traffic Hazard
# ...

# %%
df.dtypes
# Out:
# Traffic Report ID                 object
# Published Date       datetime64[ns, UTC]
# Issue Reported                    object
# Location                          object
# Latitude                         float64
# Longitude                        float64
# Address                           object
# Status                            object
# Status Date                       object
# Agency                            object
# dtype: object

# %%
df['Issue Reported'] = df['Issue Reported'].astype('string')

# %%
df.dtypes
# Out:
# Traffic Report ID                 object
# Published Date       datetime64[ns, UTC]
# Issue Reported            string[python]
# Location                          object
# Latitude                         float64
# Longitude                        float64
# Address                           object
# Status                            object
# Status Date                       object
# Agency                            object
# dtype: object

# %%
df['Issue Reported'] = df['Issue Reported'].apply(lambda x: x.lower() if pd.notnull(x) else x)

# %%
df['Issue Reported']
# Out:
# 0           stalled vehicle
# 1              crash urgent
# 2           loose livestock
# 3         trfc hazd/ debris
# 4            traffic hazard
#                 ...
# 425636        crash service
# 425637       traffic hazard
# 425638       traffic hazard
# 425639        crash service
# 425640       traffic hazard
# Name: Issue Reported, Length: 425641, dtype: object

# %%
df['Rush hour'] = df['Published Date'].dt.hour.isin(range(7,10)) | df['Published Date'].dt.hour.isin(range(16,19))

# %%
df.head()
# Out:
#                                    Traffic Report ID  \
# 0  F350D780EA8AAA48030B4DB64F790C14DBCD757F_17096...
# 1  042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 2  BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_17080...
# 3  A5909010064EF753C5F090A07CFCDDFBF25E38F3_15865...
# 4  4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_16543...
#
#              Published Date     Issue Reported                      Location  \
# 0 2024-03-06 01:29:39+00:00    stalled vehicle   POINT (-97.705874 30.32358)
# 1 2024-03-06 01:26:42+00:00       crash urgent  POINT (-97.698567 30.342505)
# 2 2024-02-15 22:17:48+00:00    loose livestock    POINT (-97.717911 30.0578)
# 3 2020-04-10 21:31:11+00:00  trfc hazd/ debris  POINT (-97.866676 30.140878)
# 4 2022-06-04 17:51:05+00:00     traffic hazard  POINT (-97.825791 30.455444)
#
#     Latitude  Longitude                                            Address  \
# 0  30.323580 -97.705874  E 290 Svrd Wb To Ih 35 Nb Ramp / N Ih 35 Svrd ...
# ...

# %%
df['Rushed Hour lambda'] = df['Published Date'].apply(lambda x: (x.hour in range(7,10)) or (x.hour in range(16,19)))

# %%
df.head(10)
# Out:
#                                    Traffic Report ID  \
# 0  F350D780EA8AAA48030B4DB64F790C14DBCD757F_17096...
# 1  042338D46C2028808F298DEC735DC7ADF0C162F6_17096...
# 2  BE73E73B642ECB6C6EDB4A52875A8017F69DFE5E_17080...
# 3  A5909010064EF753C5F090A07CFCDDFBF25E38F3_15865...
# 4  4A6C39763AD109EB75CE31C1EBFD53A0E883EE68_16543...
# 5  388082EEB5EE93B2E562236F9D37CD0B5D74F08E_17096...
# 6  09203A0B810D0C054F3F15D6DB42AA850BEA9174_17096...
# 7  0864A91883AB86909614F36A588EE81376A25C45_17096...
# 8  EE79CFC6DDF6B115A67C91FA940471B9FE90429B_17096...
# 9  619683DB9EF9D4649743EE1DEDDB3923D6E5F704_17096...
#
#              Published Date     Issue Reported                      Location  \
# 0 2024-03-06 01:29:39+00:00    stalled vehicle   POINT (-97.705874 30.32358)
# 1 2024-03-06 01:26:42+00:00       crash urgent  POINT (-97.698567 30.342505)
# 2 2024-02-15 22:17:48+00:00    loose livestock    POINT (-97.717911 30.0578)
# ...

# %%
df['Month']= df['Published Date'].dt.month
df[df['Issue Reported']=='crash urgent'].groupby('Month').size().nlargest(3)
# Out:
# Month
# 10    10059
# 11     9408
# 5      9334
# dtype: int64

# %%
df[df['Issue Reported']=='loose livestock'].groupby('Month').size().nlargest(3)
# Out:
# Month
# 9     1132
# 5     1088
# 10    1066
# dtype: int64
